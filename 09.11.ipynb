# %% [markdown]
# # 数学函数、字符串和对象
# ## 本章介绍Python函数来执行常见的数学运算
# - 函数是完成一个特殊任务的一组语句，可以理解为一个函数相当于一个小功能，但是在开发中，需要注意一个函数的长度最好不要超过一屏
# - Python中的内置函数是不需要Import导入的
# <img src="../Photo/15.png"></img>

# %%
abs(-.10) #返回参数的绝对值
# Out:
# 0.1

# %%
max([1,2,3,4]) #可迭代的
# Out:
# 4

# %%
pow(2,2) # 2的平方
# Out:
# 4

# %%
a,b,c=eval(input('输入三个数字以,分隔'))
choose_method = input('请输入你要执行的方式：max,min,pow2_sum')
if choose_method == 'max':
    max_=max(a,b,c)
    print(max_)
elif choose_method == 'min':
    min_=max(a,b,c)
    print(min_)
elif choose_method == 'pow2_sum':
    pow_sum_ = pow(a,2) + pow(b,2) + pow(c,2)
    print(pow_sum_)
# Out:
# 输入三个数字以,分隔1,2,3
# 请输入你要执行的方式：max,min,pow2_summax
# 3

# %% [markdown]
# ## Python中的math模块提供了许多数学函数
# <img src="../Photo/16.png"></img>
# <img src="../Photo/17.png"></img>

# %%
import math
math.fabs(-2)
# Out:
# 2.0

# %%
import matplotlib.pyplot as plt
list_ = []
for z in range(-50,50):
    res = 1./ (1. + math.exp(-z))
    list_.append(res)
plt.plot(list_)
plt.show()

# %%
import random
random_num = random.random()
res = 1./ (1. + math.exp(- random_num)) /2550
round(res)
# Out:
# 0

# %%
math.sqrt(2)
# Out:
# 1.4142135623730951

# %% [markdown]
# ## 两个数学常量PI和e，可以通过使用math.pi 和math.e调用

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import matplotlib.pyplot as plt
image = plt.imread('../新建文件夹/24.jpg')
plt.imshow(image)

# import matplotlib.pyplot as plt
# import numpy as np
# image = plt.imread('../新建文件夹/24.jpg')
# plt.imshow (image / math.sin(90))

# %%
import  matplotlib.pyplot as plt
image = plt.imread('../新建文件夹/24.jpg')
image2 =image.copy()
image2[:,:,2] = 255 #此处数值最大是255，相当于滤镜
plt.imshow(image2)

# %%
import  matplotlib.pyplot as plt
image =  plt.imread('../新建文件夹/24.jpg')
plt.imshow(image[::,::,::-1])

# %% [markdown]
# ## EP:
# - 通过math库，写一个程序，使得用户输入三个顶点(x,y)返回三个角度
# - 注意：Python计算角度为弧度制，需要将其转换为角度
# <img src="../Photo/18.png">

# %%
import math
x1,y1,x2,y2,x3,y3 = eval(input('请输入三个顶点：'))
a = math.sqrt((x2-x3)**2 + (y2-y3)**2)
b = math.sqrt((x3-x1)**2 + (y3-y1)**2)
c = math.sqrt((x2-x1)**2 + (y2-y1)**2)
A = math.acos((a*a - b*b - c*c)/ (-2 *b*c))
B = math.acos((b*b - a*a - c*c)/ (-2 *a*c))
C = math.acos((c*c - b*b - a*a)/ (-2 *a*b))
print(math.degrees(A),math.degrees(B),math.degrees(C)) #将弧度转换成角度
# Out:
# 请输入三个顶点：0,0,0,1,1,0
# 90.00000000000001 44.999999999999986 44.999999999999986

# %% [markdown]
# ## 字符串和字符
# - 在Python中，字符串必须是在单引号或者双引号内，在多段换行的字符串中可以使用“”“
# - 在使用”“”时，给予其变量则变为字符串，否则当多行注释使用

# %%
# 一段话要进行换行操作的话，就开头用三个引号，结尾用三个引号。
# 如果不定义的话，就相当于把这段话注释了

a='''随着计算机网络的广泛应用，确保服务的连续性变得日益重要。要保证服务的连续性，就必须使用高可用集群技术高可用集群技术
是为了确保集群对外连续不断地提供服务，实现故障检测和业务切换的自动化，提高服务器系统的运行速度和相应速度，为终端用户提供持续性的稳定服务。'''
print(a)

# '''随着计算机网络的广泛应用，确保服务的连续性变得日益重要。要保证服务的连续性，就必须使用高可用集群技术高可用集群技术
# 是为了确保集群对外连续不断地提供服务，实现故障检测和业务切换的自动化，提高服务器系统的运行速度和相应速度，为终端用户提供持续性的稳定服务。'''
# Out:
# 随着计算机网络的广泛应用，确保服务的连续性变得日益重要。要保证服务的连续性，就必须使用高可用集群技术高可用集群技术
# 是为了确保集群对外连续不断地提供服务，实现故障检测和业务切换的自动化，提高服务器系统的运行速度和相应速度，为终端用户提供持续性的稳定服务。

# %% [markdown]
# ## ASCII码与Unicode码
# - <img src="../Photo/19.png"></img>
# - <img src="../Photo/20.png"></img>
# - <img src="../Photo/21.png"></img>

# %% [markdown]
# ## 函数ord、chr
# - ord 返回ASCII码值
# - chr 返回字符

# %%
ord('a') #内置函数 返回ASCII码值
# Out:
# 97

# %%
ord('张') #接受或返回的值是十进制
# Out:
# 24352

# %%
ord(' ')
# Out:
# 32

# %%
chr(98) #返回字符串
# Out:
# 'b'

# %% [markdown]
# ## EP:
# - 利用ord与chr进行简单邮箱加密

# %%
chr(ord('a') + 10)
# Out:
# 'k'

# %%
title = 'DNN BY ZSJ'
for i in title:
    print(chr(ord(i) + 10))
# Out:
# N
# X
# X
# *
# L
# c
# *
# d
# ]
# T

# %%
title = '1939093781@qq.com'
result = ' '
for i in title:
    result = result + (chr(ord(i) + 10))
print(result)
# Out:
#  ;C=C:C=AB;J{{8myw

# %%
import hashlib
#待加密信息
str_='this is a md5 test'

#创建MD5对象
h1=hashlib.md5()

#此处必须声明encode
h1.update(str_.encode(encoding='utf-8'))  

print ('加密前为：' + str_)
print('加密后为：' + h1.hexdigest())
# Out:
# 加密前为：this is a md5 test
# 加密后为：2accb8ae19138b5de45a0e71e1ac3482

# %%
dataset = '2accb8ae19138b5de45a0e71e1ac3482'
password = input('>>')
h1=hashlib.md5()
h1.update(password.encode(encoding='utf-8'))
if dataset == h1.hexdigest():
    print('success')
else:
    print('faild')
# Out:
# >>wfdht
# faild

# %% [markdown]
# ## 转义序列 \
# - a = "He said,"Johon's program is easy to read"
# - 转掉它原来的意思
# - 一般情况下只有当语句与默认方法相撞的时候，就需要转义

# %%
a = "He said,\"Johon's program is easy to read"

# %% [markdown]
# ## 高级print
# - 参数 end： 以什么方式结束打印
# - 默认换行打印

# %%
print('a','b',sep='',end='!',flush='true') #立即刷新
# Out:
# ab!

# %% [markdown]
# ## 函数str
# - 将类型强制转换成字符串类型
# - 其他一些以后会学到(list,set,tuple...)

# %% [markdown]
# ## 字符串连接操作
# - 直接使用 “+”
# - join() 函数

# %%
'! '.join('abcd') #字符间用感叹号进行拼接   只有字符串才可以使用join
# Out:
# 'a! b! c! d'

# %%
# %time '!'.join(['1','2','3','4'])
# Out:
# Wall time: 0 ns
# '1!2!3!4'

# %% [markdown]
# ## EP：
# - 将 “Welcome” “to” "Python" 拼接
# - 将int型 100 与 “joker is a bad man” 拼接
# - 从控制台读取字符串
# > 输入一个名字返回夸奖此人

# %%
'welcome ' + 'to ' + 'python'
# Out:
# 'welcome to python'

# %%
' '.join(['100','joker is a bad man'])
# Out:
# '100 joker is a bad man'

# %%
str(100) +' '+ 'joker is a bad man'
# Out:
# '100 joker is a bad man'

# %%
name = input('>>')
print(name,'你真帅',sep='')
# Out:
# >>王源
# 王源你真帅

# %% [markdown]
# ## 实例研究：最小数量硬币
# - 开发一个程序，让用户输入总金额，这是一个用美元和美分表示的浮点值，返回一个由美元、两角五分的硬币、一角的硬币、五分硬币、以及美分个数
# <img src="../Photo/22.png"></img>

# %% [markdown]
# - Python弱项，对于浮点型的处理并不是很好，但是处理数据的时候使用的是Numpy类型
# <img src="../Photo/23.png"></img>

# %% [markdown]
# ## id与type
# - id 查看内存地址，在判断语句中将会使用
# - type 查看元素类型

# %%
type(True)
# Out:
# bool

# %%
id(1) #返回的是一个内存地址
# Out:
# 1352560096

# %%
id(2)
# Out:
# 1352560128

# %%
a = 1
id(a)
# Out:
# 1352560096

# %%
b = 2
id(b)
# Out:
# 1352560128

# %%
# a = 2                 #-5到256之间随机的两个相同的数返回的是相同的内存地址，超过256比如257返回的就是是不同的内存地址
# b = 2
# print(id(a),id(b))

a = 257   
b = 257
print(id(a),id(b))
# Out:
# 2592063647216 2592063646896

# %% [markdown]
# ## 其他格式化语句见书

# %%
print('')

# %% [markdown]
# # Homework
# - 1
# <img src="../Photo/24.png"><img>
# <img src="../Photo/25.png"><img>

# %%
import math
r = eval(input('请输入五边形顶点到中心的距离：'))
s = 2 * r * math.sin(math.pi / 5)
area = 5 * s * s / (4 * math.tan(math.pi / 5))
print('五边形面积是：',round(area,2))
# Out:
# 请输入五边形顶点到中心的距离：5.5
# 五边形面积是： 71.92

# %% [markdown]
# - 2
# <img src="../Photo/26.png"><img>

# %%
import math
x1,y1 = eval(input('输入第一个点的精度和纬度：'))
x2,y2 = eval(input('输入第二个点的精度和纬度：'))
x1 = math.radians(x1)
x2 = math.radians(x2)
y1 = math.radians(y1)
y2 = math.radians(y2)
radius = 6371.01
d = radius * math.acos(math.sin(x1) * math.sin(x2) + math.cos(x1) * math.cos(x2) * math.cos(y1 - y2))
print('大圆距离为：'+str(d)+'km')
# Out:
# 输入第一个点的精度和纬度：39.55,-116.25
# 输入第二个点的精度和纬度：41.5,87.37
# 大圆距离为：10691.79183231593km

# %% [markdown]
# - 3
# <img src="../Photo/27.png"><img>

# %%
import math
s = eval(input('输入五角形的边长：'))
area = (5 * s * s) / (4 * math.tan(math.pi / 5))
print('五角形的面积是：'+str(area))
# Out:
# 输入五角形的边长：5.5
# 五角形的面积是：52.044441367816255

# %% [markdown]
# - 4
# <img src="../Photo/28.png"><img>

# %%
import math
s = eval(input('输入边长：'))
n = eval(input('输入边的条数：'))
area = (n * s * s) / (4 * math.tan(math.pi / n))
print('面积是：'+str(area))
# Out:
# 输入边长：6.5
# 输入边的条数：5
# 面积是：72.69017017488386

# %% [markdown]
# - 5
# <img src="../Photo/29.png"><img>
# <img src="../Photo/30.png"><img>

# %%
num = eval(input('输入一个0到127之间的ASCII码值：'))
zf = chr(num)
print('对应的字符是：',zf)
# Out:
# 输入一个0到127之间的ASCII码值：69
# 对应的字符是： E

# %% [markdown]
# - 6
# <img src="../Photo/31.png"><img>

# %%
name = input('输入雇员的姓名：')
hourTime = eval(input('输入雇员一周工作的时间：'))
hourlypayRate = eval(input('输入雇员每小时报酬：'))
federalTax = eval(input('输入联邦预扣税率：'))
stateTax= eval(input('输入州预扣税率：'))

GrossPay = hourTime * hourlypayRate
federalWithholding = GrossPay * federalTax
stateWithholding = GrossPay * stateTax
totalDeduction = federalWithholding + stateWithholding
netPay = GrossPay - totalDeduction

print('雇员姓名：',name, '\n','一周工作时间：', hourTime, '\n', '每小时报酬:$', hourlypayRate,'\n',
     '总收入:$', GrossPay,'\n', '扣税:','\n', '联邦扣税额:$',federalWithholding,'\n',
      '州扣税额:$',stateWithholding,'\n', '总扣税额:$',totalDeduction ,'\n',
     '剩余工资:$', netPay)
# Out:
# 输入雇员的姓名：Simth
# 输入雇员一周工作的时间：10
# 输入雇员每小时报酬：9.75
# 输入联邦预扣税率：0.20
# 输入州预扣税率：0.09
# 雇员姓名： Simth
#  一周工作时间： 10
#  每小时报酬:$ 9.75
#  总收入:$ 97.5
#  扣税:
#  联邦扣税额:$ 19.5
#  州扣税额:$ 8.775
#  总扣税额:$ 28.275
#  剩余工资:$ 69.225

# %% [markdown]
# - 7
# <img src="../Photo/32.png"><img>

# %%
i = eval(input('输入一个四位整数'))
number = i % 10
number1 = (i // 10 ) % 10
number2 = (i // 100 )% 10
number3 = i // 1000
print( str(number) + str(number1) + str(number2) + str(number3))
# number = input('输入一个四位整数：')
# fanxiangNumber = ''
# for i in number:
#     fanxiangNumber = i + fanxiangNumber
# print('反向数字为',fanxiangNumber)
# Out:
# 输入一个四位整数3125
# 5213

# %% [markdown]
# - 8 进阶：
# > 加密一串文本，并将解密后的文件写入本地保存

# %%
import hashlib
str_='RoyWang is a handsome man'
h1=hashlib.md5()
h1.update(str_.encode(encoding='utf-8'))  

print ('加密前为：' + str_)
print('加密后为：' + h1.hexdigest())
# Out:
# 加密前为：RoyWang is a handsome man
# 加密后为：60d92a074a2b1ce8ac46ed1deea34442
